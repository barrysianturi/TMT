# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./TMT/Class 4/data_dummy.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [163], in <cell line: 1>()
# ----> 1 df = pd.read_csv("./TMT/Class 4/data_dummy.csv")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df = df[['Movement Type','Material','Quantity','Posting Date']]
df
# Out:
#         Movement Type        Material  Quantity Posting Date
# 0                 261         1902137      -1.0   2022-04-30
# 1                 261         2992544      -6.0   2022-04-30
# 2                 261         2992662      -3.0   2022-04-30
# 3                 261         2994628      -1.0   2022-04-30
# 4                 261         2995711      -3.0   2022-04-30
# ...               ...             ...       ...          ...
# 312858            601      98133134AS      -1.0   2020-01-02
# 312859            601      98157096AS      -2.0   2020-01-02
# 312860            601  CJ2-ISP0140R-7      -2.0   2020-01-02
# 312861            601    CJ2500436425      -1.0   2020-01-02
# 312862            601       CJ88112AH      -1.0   2020-01-02
#
# [312863 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312863 entries, 0 to 312862
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Movement Type  312863 non-null  int64
#  1   Material       312863 non-null  object
#  2   Quantity       312863 non-null  float64
#  3   Posting Date   312863 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 9.5+ MB

# %%
df['Posting Date'] = pd.to_datetime(df['Posting Date'])
df.head()
# Out:
#    Movement Type Material  Quantity Posting Date
# 0            261  1902137      -1.0   2022-04-30
# 1            261  2992544      -6.0   2022-04-30
# 2            261  2992662      -3.0   2022-04-30
# 3            261  2994628      -1.0   2022-04-30
# 4            261  2995711      -3.0   2022-04-30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312863 entries, 0 to 312862
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Movement Type  312863 non-null  int64
#  1   Material       312863 non-null  object
#  2   Quantity       312863 non-null  float64
#  3   Posting Date   312863 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 9.5+ MB

# %%
df.groupby('Material').sum()['Quantity'].plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='Material'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312863 entries, 0 to 312862
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Movement Type  312863 non-null  int64
#  1   Material       312863 non-null  object
#  2   Quantity       312863 non-null  float64
#  3   Posting Date   312863 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 9.5+ MB

# %%
df_Material = df.groupby('Material').count()[['Quantity']]
df_Material
# Out:
#                Quantity
# Material
# 01-103               24
# 01-104               18
# 02.5805.80.35         1
# 031.092.0-4           7
# 031.093.0-3           1
# ...                 ...
# W682000053            2
# WORK LAMP             1
# WT20M                 8
# WT20S                 5
# WT30S                 5
#
# [10558 rows x 1 columns]

# %%
df
# Out:
#        Posting Date        Material  Quantity
# 0        2022-04-30         1902137      -1.0
# 1        2022-04-30         2992544      -6.0
# 2        2022-04-30         2992662      -3.0
# 3        2022-04-30         2994628      -1.0
# 4        2022-04-30         2995711      -3.0
# ...             ...             ...       ...
# 312858   2020-01-02      98133134AS      -1.0
# 312859   2020-01-02      98157096AS      -2.0
# 312860   2020-01-02  CJ2-ISP0140R-7      -2.0
# 312861   2020-01-02    CJ2500436425      -1.0
# 312862   2020-01-02       CJ88112AH      -1.0
#
# [312863 rows x 3 columns]

# %%
dfByDateMaterial = df.groupby(['Material','Posting Date']).sum()

# %%
dfByDate = df.set_index('Posting Date')
dfByDate.resample('D').sum().plot(figsize = (16,9))
# Out:
# <AxesSubplot:xlabel='Posting Date'>

# %%
df
# Out:
#        Posting Date        Material  Quantity
# 0        2022-04-30         1902137      -1.0
# 1        2022-04-30         2992544      -6.0
# 2        2022-04-30         2992662      -3.0
# 3        2022-04-30         2994628      -1.0
# 4        2022-04-30         2995711      -3.0
# ...             ...             ...       ...
# 312858   2020-01-02      98133134AS      -1.0
# 312859   2020-01-02      98157096AS      -2.0
# 312860   2020-01-02  CJ2-ISP0140R-7      -2.0
# 312861   2020-01-02    CJ2500436425      -1.0
# 312862   2020-01-02       CJ88112AH      -1.0
#
# [312863 rows x 3 columns]

# %%
df[['Posting Date','Quantity']]
# Out:
#        Posting Date  Quantity
# 0        2022-04-30      -1.0
# 1        2022-04-30      -6.0
# 2        2022-04-30      -3.0
# 3        2022-04-30      -1.0
# 4        2022-04-30      -3.0
# ...             ...       ...
# 312858   2020-01-02      -1.0
# 312859   2020-01-02      -2.0
# 312860   2020-01-02      -2.0
# 312861   2020-01-02      -1.0
# 312862   2020-01-02      -1.0
#
# [312863 rows x 2 columns]

# %%
dfByDate = df[['Posting Date','Quantity']].resample('D').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [123], in <cell line: 1>()
# ----> 1 dfByDate = df[['Posting Date','Quantity']].resample('D').mean()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:10541, in DataFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#   10525 @doc(NDFrame.resample, **_shared_doc_kwargs)
#   10526 def resample(
#   10527     self,
#    (...)
#   10539     offset: TimedeltaConvertibleTypes | None = None,
#   10540 ) -> Resampler:
# > 10541     return super().resample(
#   10542         rule=rule,
#   10543         axis=axis,
#   10544         closed=closed,
#   10545         label=label,
#   10546         convention=convention,
#   10547         kind=kind,
#   10548         loffset=loffset,
#   10549         base=base,
#   10550         on=on,
# ...

# %%
df_by_date = df.groupby(['Posting Date'],as_index=False)['Quantity'].sum()
fig, ax = plt.subplots(figsize=(12,9))
sns.lineplot(x='Posting Date', y='Quantity', data=df_by_date)
# Out:
# <AxesSubplot:xlabel='Posting Date', ylabel='Quantity'>

# %%
# Out:
#               Quantity
# Posting Date
# 2019-05-01      -219.0
# 2019-05-02      -301.0
# 2019-05-03     -1240.0
# 2019-05-04      -206.0
# 2019-05-05       -53.0
# ...                ...
# 2022-04-26     -1373.0
# 2022-04-27     -1133.0
# 2022-04-28      -485.5
# 2022-04-29      -189.0
# 2022-04-30       -88.0
#
# [1096 rows x 1 columns]
