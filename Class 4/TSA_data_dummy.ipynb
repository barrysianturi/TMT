# %%
import pandas as pd

# %%
dfTransaksi = pd.read_excel("Data Transaksi 2019 - 2022.xlsx")
dfTransaksi.head()
# Out:
#   Plant Storage Location  Movement Type  Material Doc.Item Material  \
# 0  7M39             7M39            261                  9  1902137
# 1  7M39             7M39            261                  1  2992544
# 2  7M39             7M39            261                  2  2992662
# 3  7M39             7M39            261                  5  2994628
# 4  7M39             7M39            261                  3  2995711
#
#    Material Description  Quantity  Amount in LC  Purchase Order Reference  \
# 0     HYDROSTEER.FILTER      -1.0         -4.19             NaN       NaN
# 1            OIL FILTER      -6.0        -87.24             NaN       NaN
# 2  FUEL PRE-FIL. CARTR.      -3.0        -33.87             NaN       NaN
# 3        KIT WIPERBLADE      -1.0        -12.43             NaN       NaN
# 4    FUEL FILTER CARTR.      -3.0        -33.30             NaN       NaN
#
#        Order  Material Document Document Header Text Customer   User Name  \
# ...

# %%
dfTransaksi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312863 entries, 0 to 312862
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Plant                 312863 non-null  object
#  1   Storage Location      312863 non-null  object
#  2   Movement Type         312863 non-null  int64
#  3   Material Doc.Item     312863 non-null  int64
#  4   Material              312863 non-null  object
#  5   Material Description  312863 non-null  object
#  6   Quantity              312863 non-null  float64
#  7   Amount in LC          312863 non-null  float64
#  8   Purchase Order        0 non-null       float64
#  9   Reference             216206 non-null  object
#  10  Order                 126563 non-null  float64
#  11  Material Document     312863 non-null  int64
#  12  Document Header Text  50292 non-null   object
#  13  Customer              186300 non-null  object
# ...

# %%
df = dfTransaksi[['Posting Date', 'Material','Quantity']]
df.head()
# Out:
#   Posting Date Material  Quantity
# 0   2022-04-30  1902137      -1.0
# 1   2022-04-30  2992544      -6.0
# 2   2022-04-30  2992662      -3.0
# 3   2022-04-30  2994628      -1.0
# 4   2022-04-30  2995711      -3.0

# %%
df.to_csv("data_dummy.csv")

# %%
len(df)
# Out:
# 312863

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312863 entries, 0 to 312862
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Posting Date  312863 non-null  datetime64[ns]
#  1   Material      312863 non-null  object
#  2   Quantity      312863 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 7.2+ MB

# %%
df.describe()
# Out:
#             Quantity
# count  312863.000000
# mean       -2.514806
# std        12.373541
# min     -4180.000000
# 25%        -2.000000
# 50%        -1.000000
# 75%        -1.000000
# max      2160.000000
